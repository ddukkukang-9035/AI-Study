# %% [markdown]
# <a href="https://colab.research.google.com/github/ddukkukang-9035/AI-Study/blob/main/20260908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt')
nltk.download('webtext')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize, sent_tokenize
text = "Alice loves cats. she also likes dogs."
print(sent_tokenize(text))
print(word_tokenize(text))

from nltk.corpus import webtext
print(webtext.fileids())

print(webtext.words('grail.txt')[:20])

from nltk.corpus import wordnet
syns = wordnet.synsets("good")
print(syns[0].definition())
print(syns[0].examples())

from nltk.corpus import stopwords
print(stopwords.words('english')[:20])

import nltk

def ensure_nltk_resources():
    needed = [
        ("tokenizers/punkt", "punkt"),
        ("taggers/averaged_perceptron_tagger", "averaged_perceptron_tagger"),
        ("taggers/averaged_perceptron_tagger_eng", "averaged_perceptron_tagger_eng")
    ]
    for path, pkg in needed:
        try:
            nltk.data.find(path)
        except LookupError:
            nltk.download(pkg, quiet=True)

ensure_nltk_resources()

tokens=nltk.word_tokenize("Alice is. looking at the cat. ")
pos_tags = nltk.pos_tag(tokens, lang="eng")
print(pos_tags)
# Out:
# ['Alice loves cats.', 'she also likes dogs.']
# ['Alice', 'loves', 'cats', '.', 'she', 'also', 'likes', 'dogs', '.']
# ['firefox.txt', 'grail.txt', 'overheard.txt', 'pirates.txt', 'singles.txt', 'wine.txt']
# ['SCENE', '1', ':', '[', 'wind', ']', '[', 'clop', 'clop', 'clop', ']', 'KING', 'ARTHUR', ':', 'Whoa', 'there', '!', '[', 'clop', 'clop']
# benefit
# ['for your own good', "what's the good of worrying?"]
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been']
# [('Alice', 'NNP'), ('is', 'VBZ'), ('.', '.'), ('looking', 'VBG'), ('at', 'IN'), ('the', 'DT'), ('cat', 'NN'), ('.', '.')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ...
